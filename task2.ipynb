# %% [markdown]
# # Задание 2

# %% [markdown]
# ## 2.1 Задачи на регулярные выражения
# ---
# 1. Напишите регулярное выражение, которое возвращает список первых двух букв каждого слова строки. Обратите внимание на работу с дефисом.
# 2. Напишите регулярное выражение, которое выбирает из строки все слова, в которых строго больше 3 символов.
# 3. Напишите регулярное выражение, которое заменит все подстроки, обозначающие время (только время, не даты), в строке на TBD.
# 4. Напишите регулярное выражение, которое заменяет произвольное количество пробельных символов внутри строки на один пробел.
# 5. Напишите регулярное выражение, которое удаляет идущие подряд повторы. Одно слово из группы должно остаться.
# 6. Напишите регулярное выражение, которое определяет, что подстрока является адресом электронной почты.
# 7. Напишите регулярное выражение, которое возвращает список аббревиатур в строке.
# 8. Напишите регулярное выражение, которое разделяет текст на предложения.
# 9. Напишите регулярное выражение, которое определяет, что строка является номером российского мобильного телефона любого оператора.
# 10. Напишите регулярное выражение, которое проверяет, что все предложения в строке начинаются с заглавной буквы.

# %% [markdown]
# Помимо лекционных материалов отличный гайд по регулярным выражениям с хабра: <https://habr.com/ru/post/349860/>

# %%
import re
import json

# %%
text = "Наш мир живет в ситуации глобализации. Национальные и культурные границы более прозрачны, чем раньше. Люди путешествуют по всему миру с разными целями: чтобы отдыхать и смотреть на другие страны (туризм), работать (международный бизнес) и учиться (образовательный обмен). Иногда чьи-то родственники или друзья живут за границей, и поездки туда становятся регулярными. Конечно, каждому нужен удобный и доступный способ путешествовать на дальние расстояния. Некоторые люди предпочитают традиционные поезда, но не все железные дороги проходят через государственные границы. Кроме того, путешествие на поезде обычно занимает много времени. Что касается путешествий по морю, они тоже могут быть невозможными (например, между странами Центральной Европы) или вызывать плохое самочувствие. Поэтому наиболее популярный способ ездить за границу – путешествие на самолете. Самолет – не самое дешевое, но самое быстрое и комфортное транспортное средство, позволяющее пересекать континенты и океаны всего за несколько часов. Путешественник может выбрать рейс, купить билет и забронировать место заранее, через Интернет. Нет необходимости носить тяжелый чемодан, так как багаж доставляется отдельно, после контроля его веса и содержимого. Хотя процедуры таможенного контроля довольно долгие, они гарантируют безопасность пассажиров во время полета. Есть другая точка зрения: некоторые люди считают, что путешествовать на самолете очень опасно. Однако современные самолеты технически усовершенствованы и оборудованы всеми защитными средствами. Только высококвалифицированные пилоты и стюарды могут обслуживать их. На мой взгляд, путешествия на самолете безопасны и приятны."

# %%
print(text, '\n\nОбъём текста: {} слов'.format(len(text)))
# Out:
# Наш мир живет в ситуации глобализации. Национальные и культурные границы более прозрачны, чем раньше. Люди путешествуют по всему миру с разными целями: чтобы отдыхать и смотреть на другие страны (туризм), работать (международный бизнес) и учиться (образовательный обмен). Иногда чьи-то родственники или друзья живут за границей, и поездки туда становятся регулярными. Конечно, каждому нужен удобный и доступный способ путешествовать на дальние расстояния. Некоторые люди предпочитают традиционные поезда, но не все железные дороги проходят через государственные границы. Кроме того, путешествие на поезде обычно занимает много времени. Что касается путешествий по морю, они тоже могут быть невозможными (например, между странами Центральной Европы) или вызывать плохое самочувствие. Поэтому наиболее популярный способ ездить за границу – путешествие на самолете. Самолет – не самое дешевое, но самое быстрое и комфортное транспортное средство, позволяющее пересекать континенты и океаны всего за несколько часов. Путешественник может выбрать рейс, купить билет и забронировать место заранее, через Интернет. Нет необходимости носить тяжелый чемодан, так как багаж доставляется отдельно, после контроля его веса и содержимого. Хотя процедуры таможенного контроля довольно долгие, они гарантируют безопасность пассажиров во время полета. Есть другая точка зрения: некоторые люди считают, что путешествовать на самолете очень опасно. Однако современные самолеты технически усовершенствованы и оборудованы всеми защитными средствами. Только высококвалифицированные пилоты и стюарды могут обслуживать их. На мой взгляд, путешествия на самолете безопасны и приятны.
#
# Объём текста: 1659 слов

# %% [markdown]
# ---

# %% [markdown]
# ### 2.1.1. Напишите регулярное выражение, которое возвращает список первых двух букв каждого слова строки. Обратите внимание на работу с дефисом.

# %% [markdown]
# Если мы **не показываем** слова из одной буквы:

# %%
result = re.findall(r'\b\w\w', text)
result
# Out:
# ['На',
#  'ми',
#  'жи',
#  'си',
#  'гл',
#  'На',
#  'ку',
#  'гр',
#  'бо',
#  'пр',
#  'че',
#  'ра',
#  'Лю',
#  'пу',
#  'по',
#  'вс',
#  'ми',
#  'ра',
#  'це',
#  'чт',
#  'от',
#  'см',
#  'на',
#  'др',
#  'ст',
#  'ту',
#  'ра',
#  'ме',
#  'би',
#  'уч',
#  'об',
#  'об',
#  'Ин',
#  'чь',
#  'то',
#  'ро',
#  'ил',
#  'др',
#  'жи',
#  'за',
#  'гр',
#  'по',
#  'ту',
#  'ст',
#  'ре',
#  'Ко',
#  'ка',
#  'ну',
#  'уд',
#  'до',
#  'сп',
#  'пу',
#  'на',
#  'да',
#  'ра',
#  'Не',
#  'лю',
#  'пр',
#  'тр',
#  'по',
#  'но',
#  'не',
#  'вс',
#  'же',
#  'до',
#  'пр',
#  'че',
#  'го',
#  'гр',
#  'Кр',
#  'то',
#  'пу',
#  'на',
#  'по',
#  'об',
#  'за',
#  'мн',
#  'вр',
#  'Чт',
#  'ка',
#  'пу',
#  'по',
#  'мо',
#  'он',
#  'то',
#  'мо',
#  'бы',
#  'не',
#  'на',
#  'ме',
#  'ст',
#  'Це',
#  'Ев',
#  'ил',
#  'вы',
#  'пл',
#  'са',
#  'По',
#  'на',
#  'по',
#  'сп',
#  'ез',
#  'за',
#  'гр',
#  'пу',
#  'на',
#  'са',
#  'Са',
#  'не',
#  'са',
#  'де',
#  'но',
#  'са',
#  'бы',
#  'ко',
#  'тр',
#  'ср',
#  'по',
#  'пе',
#  'ко',
#  'ок',
#  'вс',
#  'за',
#  'не',
#  'ча',
#  'Пу',
#  'мо',
#  'вы',
#  'ре',
#  'ку',
#  'би',
#  'за',
#  'ме',
#  'за',
#  'че',
#  'Ин',
#  'Не',
#  'не',
#  'но',
#  'тя',
#  'че',
#  'та',
#  'ка',
#  'ба',
#  'до',
#  'от',
#  'по',
#  'ко',
#  'ег',
#  'ве',
#  'со',
#  'Хо',
#  'пр',
#  'та',
#  'ко',
#  'до',
#  'до',
#  'он',
#  'га',
#  'бе',
#  'па',
#  'во',
#  'вр',
#  'по',
#  'Ес',
#  'др',
#  'то',
#  'зр',
#  'не',
#  'лю',
#  'сч',
#  'чт',
#  'пу',
#  'на',
#  'са',
#  'оч',
#  'оп',
#  'Од',
#  'со',
#  'са',
#  'те',
#  'ус',
#  'об',
#  'вс',
#  'за',
#  'ср',
#  'То',
#  'вы',
#  'пи',
#  'ст',
#  'мо',
#  'об',
#  'их',
#  'На',
#  'мо',
#  'вз',
#  'пу',
#  'на',
#  'са',
#  'бе',
#  'пр']

# %% [markdown]
# Если мы **показываем слова** из одной буквы:

# %%
re.findall(r'\b\w{1,2}', text)
# Out:
# ['На',
#  'ми',
#  'жи',
#  'в',
#  'си',
#  'гл',
#  'На',
#  'и',
#  'ку',
#  'гр',
#  'бо',
#  'пр',
#  'че',
#  'ра',
#  'Лю',
#  'пу',
#  'по',
#  'вс',
#  'ми',
#  'с',
#  'ра',
#  'це',
#  'чт',
#  'от',
#  'и',
#  'см',
#  'на',
#  'др',
#  'ст',
#  'ту',
#  'ра',
#  'ме',
#  'би',
#  'и',
#  'уч',
#  'об',
#  'об',
#  'Ин',
#  'чь',
#  'то',
#  'ро',
#  'ил',
#  'др',
#  'жи',
#  'за',
#  'гр',
#  'и',
#  'по',
#  'ту',
#  'ст',
#  'ре',
#  'Ко',
#  'ка',
#  'ну',
#  'уд',
#  'и',
#  'до',
#  'сп',
#  'пу',
#  'на',
#  'да',
#  'ра',
#  'Не',
#  'лю',
#  'пр',
#  'тр',
#  'по',
#  'но',
#  'не',
#  'вс',
#  'же',
#  'до',
#  'пр',
#  'че',
#  'го',
#  'гр',
#  'Кр',
#  'то',
#  'пу',
#  'на',
#  'по',
#  'об',
#  'за',
#  'мн',
#  'вр',
#  'Чт',
#  'ка',
#  'пу',
#  'по',
#  'мо',
#  'он',
#  'то',
#  'мо',
#  'бы',
#  'не',
#  'на',
#  'ме',
#  'ст',
#  'Це',
#  'Ев',
#  'ил',
#  'вы',
#  'пл',
#  'са',
#  'По',
#  'на',
#  'по',
#  'сп',
#  'ез',
#  'за',
#  'гр',
#  'пу',
#  'на',
#  'са',
#  'Са',
#  'не',
#  'са',
#  'де',
#  'но',
#  'са',
#  'бы',
#  'и',
#  'ко',
#  'тр',
#  'ср',
#  'по',
#  'пе',
#  'ко',
#  'и',
#  'ок',
#  'вс',
#  'за',
#  'не',
#  'ча',
#  'Пу',
#  'мо',
#  'вы',
#  'ре',
#  'ку',
#  'би',
#  'и',
#  'за',
#  'ме',
#  'за',
#  'че',
#  'Ин',
#  'Не',
#  'не',
#  'но',
#  'тя',
#  'че',
#  'та',
#  'ка',
#  'ба',
#  'до',
#  'от',
#  'по',
#  'ко',
#  'ег',
#  'ве',
#  'и',
#  'со',
#  'Хо',
#  'пр',
#  'та',
#  'ко',
#  'до',
#  'до',
#  'он',
#  'га',
#  'бе',
#  'па',
#  'во',
#  'вр',
#  'по',
#  'Ес',
#  'др',
#  'то',
#  'зр',
#  'не',
#  'лю',
#  'сч',
#  'чт',
#  'пу',
#  'на',
#  'са',
#  'оч',
#  'оп',
#  'Од',
#  'со',
#  'са',
#  'те',
#  'ус',
#  'и',
#  'об',
#  'вс',
#  'за',
#  'ср',
#  'То',
#  'вы',
#  'пи',
#  'и',
#  'ст',
#  'мо',
#  'об',
#  'их',
#  'На',
#  'мо',
#  'вз',
#  'пу',
#  'на',
#  'са',
#  'бе',
#  'и',
#  'пр']

# %% [markdown]
# Какие операторы использовались?
#
# | Оператор | Что он делает |
# |:-:|:-:|
# | \b | граница слова |
# | \w | любая цифра или буква |
# | {n, m} | от n до m вхождений |

# %% [markdown]
# ---

# %% [markdown]
# ### 2.1.2. Напишите регулярное выражение, которое выбирает из строки все слова, в которых строго больше 3 символов.

# %%
re.findall(r'\S{4,}', text)
# Out:
# ['живет',
#  'ситуации',
#  'глобализации.',
#  'Национальные',
#  'культурные',
#  'границы',
#  'более',
#  'прозрачны,',
#  'раньше.',
#  'Люди',
#  'путешествуют',
#  'всему',
#  'миру',
#  'разными',
#  'целями:',
#  'чтобы',
#  'отдыхать',
#  'смотреть',
#  'другие',
#  'страны',
#  '(туризм),',
#  'работать',
#  '(международный',
#  'бизнес)',
#  'учиться',
#  '(образовательный',
#  'обмен).',
#  'Иногда',
#  'чьи-то',
#  'родственники',
#  'друзья',
#  'живут',
#  'границей,',
#  'поездки',
#  'туда',
#  'становятся',
#  'регулярными.',
#  'Конечно,',
#  'каждому',
#  'нужен',
#  'удобный',
#  'доступный',
#  'способ',
#  'путешествовать',
#  'дальние',
#  'расстояния.',
#  'Некоторые',
#  'люди',
#  'предпочитают',
#  'традиционные',
#  'поезда,',
#  'железные',
#  'дороги',
#  'проходят',
#  'через',
#  'государственные',
#  'границы.',
#  'Кроме',
#  'того,',
#  'путешествие',
#  'поезде',
#  'обычно',
#  'занимает',
#  'много',
#  'времени.',
#  'касается',
#  'путешествий',
#  'морю,',
#  'тоже',
#  'могут',
#  'быть',
#  'невозможными',
#  '(например,',
#  'между',
#  'странами',
#  'Центральной',
#  'Европы)',
#  'вызывать',
#  'плохое',
#  'самочувствие.',
#  'Поэтому',
#  'наиболее',
#  'популярный',
#  'способ',
#  'ездить',
#  'границу',
#  'путешествие',
#  'самолете.',
#  'Самолет',
#  'самое',
#  'дешевое,',
#  'самое',
#  'быстрое',
#  'комфортное',
#  'транспортное',
#  'средство,',
#  'позволяющее',
#  'пересекать',
#  'континенты',
#  'океаны',
#  'всего',
#  'несколько',
#  'часов.',
#  'Путешественник',
#  'может',
#  'выбрать',
#  'рейс,',
#  'купить',
#  'билет',
#  'забронировать',
#  'место',
#  'заранее,',
#  'через',
#  'Интернет.',
#  'необходимости',
#  'носить',
#  'тяжелый',
#  'чемодан,',
#  'багаж',
#  'доставляется',
#  'отдельно,',
#  'после',
#  'контроля',
#  'веса',
#  'содержимого.',
#  'Хотя',
#  'процедуры',
#  'таможенного',
#  'контроля',
#  'довольно',
#  'долгие,',
#  'гарантируют',
#  'безопасность',
#  'пассажиров',
#  'время',
#  'полета.',
#  'Есть',
#  'другая',
#  'точка',
#  'зрения:',
#  'некоторые',
#  'люди',
#  'считают,',
#  'путешествовать',
#  'самолете',
#  'очень',
#  'опасно.',
#  'Однако',
#  'современные',
#  'самолеты',
#  'технически',
#  'усовершенствованы',
#  'оборудованы',
#  'всеми',
#  'защитными',
#  'средствами.',
#  'Только',
#  'высококвалифицированные',
#  'пилоты',
#  'стюарды',
#  'могут',
#  'обслуживать',
#  'взгляд,',
#  'путешествия',
#  'самолете',
#  'безопасны',
#  'приятны.']

# %% [markdown]
# Какие операторы использовались?
#
# | Оператор | Что он делает |
# |:-:|:-:|
# | \S | любой непробельный символ |
# | {n,} | Не менее n повторений |

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2.3. Напишите регулярное выражение, которое заменит все подстроки, обозначающие время (только время, не даты), в строке на 'TBD'.

# %%
subtext1 = 'Он обещал приехать ровно в 14:31:58, но приедет не раньше 15:00'

pattern = r'((?:[01]\d|2[0-3])\:(?:[0-5]\d)(?:\:[0-5]\d)?)'
newsubtext1 = re.sub(pattern, "TBD", subtext1)

print(newsubtext1)
# Out:
# Он обещал приехать ровно в TBD, но приедет не раньше TBD

# %% [markdown]
# Какие операторы использовались?
#
# | Оператор | Что он делает |
# |:-:|:-:|
# | \d | любая цифра [0-9] |
# | [..] | один из символов в скобках |
# | \ | экранирование спецсимволов |
# | ? | 0 или 1 вхождение шаблона, стоящего перед ? |
# | a\|b | равно a или b |

# %% [markdown]
# ---
